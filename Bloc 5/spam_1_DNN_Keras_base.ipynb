# %% [markdown]
# ---
# # DNN : `spam` (avec `Keras`, version de base)
# ---

# %% [markdown]
# ## Packages

# %%
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from keras import layers, models

# %% [markdown]
# ---
# ## 1. Données
# ---

# %% [markdown]
# ### 1.1. Importation

# %%
# En local :
directory = ''

# Sur Google collab ou Onyxia (sur un répertoire temporaire) :
# directory = ''

# Sur Google collab (sur le drive) :
# from google.colab import drive
# drive.mount('/content/drive')
# directory = '/content/drive/MyDrive/Data/'

# %%
data = pd.read_csv(directory + 'spam.csv',
                   header    = 0,
                   # index_col = 0,
                   sep       = ',',
                   decimal   = '.')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
#  13  word_freq_report            4601 non-null   float64
#  14  word_freq_addresses         4601 non-null   float64
#  15  word_freq_free              4601 non-null   float64
#  16  word_freq_business          4601 non-null   float64
#  17  word_freq_email             4601 non-null   float64
#  18  word_freq_you               4601 non-null   float64
#  19  word_freq_credit            4601 non-null   float64
#  20  word_freq_your              4601 non-null   float64
#  21  word_freq_font              4601 non-null   float64
#  22  word_freq_000               4601 non-null   float64
#  23  word_freq_money             4601 non-null   float64
#  24  word_freq_hp                4601 non-null   float64
#  25  word_freq_hpl               4601 non-null   float64
#  26  word_freq_george            4601 non-null   float64
#  27  word_freq_650               4601 non-null   float64
#  28  word_freq_lab               4601 non-null   float64
#  29  word_freq_labs              4601 non-null   float64
#  30  word_freq_telnet            4601 non-null   float64
#  31  word_freq_857               4601 non-null   float64
#  32  word_freq_data              4601 non-null   float64
#  33  word_freq_415               4601 non-null   float64
#  34  word_freq_85                4601 non-null   float64
#  35  word_freq_technology        4601 non-null   float64
#  36  word_freq_1999              4601 non-null   float64
#  37  word_freq_parts             4601 non-null   float64
#  38  word_freq_pm                4601 non-null   float64
#  39  word_freq_direct            4601 non-null   float64
#  40  word_freq_cs                4601 non-null   float64
#  41  word_freq_meeting           4601 non-null   float64
#  42  word_freq_original          4601 non-null   float64
#  43  word_freq_project           4601 non-null   float64
#  44  word_freq_re                4601 non-null   float64
#  45  word_freq_edu               4601 non-null   float64
#  46  word_freq_table             4601 non-null   float64
#  47  word_freq_conference        4601 non-null   float64
#  48  char_freq_semicolon         4601 non-null   float64
#  49  char_freq_leftbrac          4601 non-null   float64
#  50  char_freq_leftsquarebrac    4601 non-null   float64
#  51  char_freq_exclaim           4601 non-null   float64
#  52  char_freq_dollar            4601 non-null   float64
#  53  char_freq_pound             4601 non-null   float64
#  54  capital_run_length_average  4601 non-null   float64
#  55  capital_run_length_longest  4601 non-null   int64
#  56  capital_run_length_total    4601 non-null   int64
#  57  spam                        4601 non-null   int64
# dtypes: float64(55), int64(3)
# memory usage: 2.0 MB

# %%
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_semicolon  \
# 0             0.00            0.00  ...                 0.00
# 1             0.00            0.94  ...                 0.00
# 2             0.64            0.25  ...                 0.01
# 3             0.31            0.63  ...                 0.00
# 4             0.31            0.63  ...                 0.00
#
#    char_freq_leftbrac  char_freq_leftsquarebrac  char_freq_exclaim  \
# 0               0.000                       0.0              0.778
# 1               0.132                       0.0              0.372
# 2               0.143                       0.0              0.276
# 3               0.137                       0.0              0.137
# 4               0.135                       0.0              0.135
#
#    char_freq_dollar  char_freq_pound  capital_run_length_average  \
# 0             0.000            0.000                       3.756
# 1             0.180            0.048                       5.114
# 2             0.184            0.010                       9.821
# 3             0.000            0.000                       3.537
# 4             0.000            0.000                       3.537
#
#    capital_run_length_longest  capital_run_length_total  spam
# 0                          61                       278     1
# 1                         101                      1028     1
# 2                         485                      2259     1
# 3                          40                       191     1
# 4                          40                       191     1
#
# [5 rows x 58 columns]

# %% [markdown]
# ### 1.2. Gestion des données manquantes

# %%
missing_percentage = data.isna().mean() * 100

print('MISSING VALUES :')
if missing_percentage[missing_percentage != 0].empty:
    print('No')
else:
    print(missing_percentage[missing_percentage != 0].sort_values(ascending=False))
# Out:
# MISSING VALUES :
# No

# %% [markdown]
# ### 1.3. Gestion des variables

# %%
target = 'spam'

y = data[target]
X = data.drop(target, axis=1)

# %% [markdown]
# ### 1.4. Création des échantillons de validation et test

# %%
test_portion  = 1/5
valid_portion = 1/5

X_train_valid, X_test, y_train_valid, y_test = train_test_split(X, y, test_size=test_portion)

X_train, X_valid, y_train, y_valid = train_test_split(X_train_valid, y_train_valid, test_size=valid_portion)

print('Dimensions de X_train :', X_train.shape)
print('Dimensions de X_valid :', X_valid.shape)
print('Dimensions de X_test  :', X_test.shape)

print('Dimensions de y_train :', y_train.shape)
print('Dimensions de y_valid :', y_valid.shape)
print('Dimensions de y_test  :', y_test.shape)
# Out:
# Dimensions de X_train : (2944, 57)
# Dimensions de X_valid : (736, 57)
# Dimensions de X_test  : (921, 57)
# Dimensions de y_train : (2944,)
# Dimensions de y_valid : (736,)
# Dimensions de y_test  : (921,)

# %% [markdown]
# ### 1.5. Normalisation des covariables

# %% [markdown]
# On normalise (centrage-réduction) les covariables :

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train_norm = scaler.transform(X_train)
X_valid_norm = scaler.transform(X_valid)
X_test_norm  = scaler.transform(X_test)

# %% [markdown]
# ---
# ## 2. DNN
# ---

# %% [markdown]
# ### 2.1. Architecture

# %%
dim_inputs  = (X_train_norm.shape[1],)
dim_outputs = 1

n_units_hl1 = 50
n_units_hl2 = 30

model = models.Sequential(name='DNN')

model.add(layers.Input(shape=dim_inputs, name='Inputs'))

model.add(layers.Dense(units=n_units_hl1, activation='relu', name='Hidden_layer_1'))

model.add(layers.Dense(units=n_units_hl2, activation='relu', name='Hidden_layer_2'))

model.add(layers.Dense(units=dim_outputs, activation='sigmoid', name='Output_layer'))

model.summary()
# Out:
# 2025-10-01 13:34:33.232518: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "DNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_layer_1 (Dense)          │ (None, 50)             │         2,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_layer_2 (Dense)          │ (None, 30)             │         1,530 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_layer (Dense)            │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,461 (17.43 KB)
#  Trainable params: 4,461 (17.43 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 2.2. Optimiseur

# %%
model.compile(optimizer = 'adam',
              loss      = 'binary_crossentropy',
              metrics   = ['accuracy'])

# %% [markdown]
# ### 2.3. Entraînement

# %%
hist = model.fit(X_train_norm,
                 y_train,
                 batch_size      = 500,
                 epochs          = 200,
                 validation_data = (X_valid_norm, y_valid),
                 verbose         = 1)
# Out:
# Epoch 1/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 842ms/step - accuracy: 0.6593 - loss: 0.6302 - val_accuracy: 0.7092 - val_loss: 0.5954
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 421ms/step - accuracy: 0.7558 - loss: 0.5522 - val_accuracy: 0.7677 - val_loss: 0.5332
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 342ms/step - accuracy: 0.8159 - loss: 0.4883 - val_accuracy: 0.8152 - val_loss: 0.4817
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 318ms/step - accuracy: 0.8580 - loss: 0.4332 - val_accuracy: 0.8451 - val_loss: 0.4379
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 379ms/step - accuracy: 0.8787 - loss: 0.3860 - val_accuracy: 0.8505 - val_loss: 0.4015
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 481ms/step - accuracy: 0.8920 - loss: 0.3462 - val_accuracy: 0.8641 - val_loss: 0.3723
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 401ms/step - accuracy: 0.9005 - loss: 0.3144 - val_accuracy: 0.8764 - val_loss: 0.3488
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 494ms/step - accuracy: 0.9062 - loss: 0.2883 - val_accuracy: 0.8899 - val_loss: 0.3293
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 382ms/step - accuracy: 0.9124 - loss: 0.2674 - val_accuracy: 0.9022 - val_loss: 0.3134
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 338ms/step - accuracy: 0.9154 - loss: 0.2515 - val_accuracy: 0.9090 - val_loss: 0.2999
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 387ms/step - accuracy: 0.9205 - loss: 0.2379 - val_accuracy: 0.9090 - val_loss: 0.2886
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 203ms/step - accuracy: 0.9229 - loss: 0.2270 - val_accuracy: 0.9144 - val_loss: 0.2784
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 312ms/step - accuracy: 0.9256 - loss: 0.2179 - val_accuracy: 0.9144 - val_loss: 0.2702
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.9270 - loss: 0.2097 - val_accuracy: 0.9144 - val_loss: 0.2630
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 418ms/step - accuracy: 0.9297 - loss: 0.2027 - val_accuracy: 0.9171 - val_loss: 0.2572
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 377ms/step - accuracy: 0.9314 - loss: 0.1962 - val_accuracy: 0.9226 - val_loss: 0.2516
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 341ms/step - accuracy: 0.9334 - loss: 0.1905 - val_accuracy: 0.9253 - val_loss: 0.2454
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 328ms/step - accuracy: 0.9344 - loss: 0.1852 - val_accuracy: 0.9239 - val_loss: 0.2407
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.9348 - loss: 0.1801 - val_accuracy: 0.9239 - val_loss: 0.2359
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 390ms/step - accuracy: 0.9392 - loss: 0.1758 - val_accuracy: 0.9266 - val_loss: 0.2315
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 419ms/step - accuracy: 0.9409 - loss: 0.1713 - val_accuracy: 0.9253 - val_loss: 0.2281
# Epoch 22/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 337ms/step - accuracy: 0.9412 - loss: 0.1676 - val_accuracy: 0.9266 - val_loss: 0.2239
# Epoch 23/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 358ms/step - accuracy: 0.9426 - loss: 0.1637 - val_accuracy: 0.9280 - val_loss: 0.2196
# Epoch 24/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 241ms/step - accuracy: 0.9436 - loss: 0.1602 - val_accuracy: 0.9293 - val_loss: 0.2163
# Epoch 25/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step - accuracy: 0.9450 - loss: 0.1568 - val_accuracy: 0.9307 - val_loss: 0.2129
# Epoch 26/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 297ms/step - accuracy: 0.9474 - loss: 0.1538 - val_accuracy: 0.9307 - val_loss: 0.2097
# Epoch 27/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 499ms/step - accuracy: 0.9477 - loss: 0.1510 - val_accuracy: 0.9348 - val_loss: 0.2072
# Epoch 28/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 240ms/step - accuracy: 0.9494 - loss: 0.1483 - val_accuracy: 0.9361 - val_loss: 0.2055
# Epoch 29/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.9487 - loss: 0.1456 - val_accuracy: 0.9348 - val_loss: 0.2036
# Epoch 30/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.
# Epoch 171/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9932 - loss: 0.0294 - val_accuracy: 0.9497 - val_loss: 0.2260
# Epoch 172/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.9929 - loss: 0.0303 - val_accuracy: 0.9497 - val_loss: 0.2318
# Epoch 173/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9929 - loss: 0.0290 - val_accuracy: 0.9511 - val_loss: 0.2252
# Epoch 174/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9922 - loss: 0.0286 - val_accuracy: 0.9497 - val_loss: 0.2303
# Epoch 175/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9939 - loss: 0.0270 - val_accuracy: 0.9497 - val_loss: 0.2267
# Epoch 176/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9932 - loss: 0.0276 - val_accuracy: 0.9470 - val_loss: 0.2322
# Epoch 177/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9935 - loss: 0.0271 - val_accuracy: 0.9470 - val_loss: 0.2322
# Epoch 178/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9935 - loss: 0.0264 - val_accuracy: 0.9470 - val_loss: 0.2310
# Epoch 179/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9925 - loss: 0.0261 - val_accuracy: 0.9484 - val_loss: 0.2335
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9935 - loss: 0.0259 - val_accuracy: 0.9470 - val_loss: 0.2351
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9935 - loss: 0.0257 - val_accuracy: 0.9470 - val_loss: 0.2351
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9932 - loss: 0.0258 - val_accuracy: 0.9470 - val_loss: 0.2350
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9929 - loss: 0.0254 - val_accuracy: 0.9470 - val_loss: 0.2379
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9932 - loss: 0.0250 - val_accuracy: 0.9497 - val_loss: 0.2371
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9935 - loss: 0.0248 - val_accuracy: 0.9470 - val_loss: 0.2390
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9939 - loss: 0.0243 - val_accuracy: 0.9484 - val_loss: 0.2370
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9932 - loss: 0.0241 - val_accuracy: 0.9470 - val_loss: 0.2407
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9929 - loss: 0.0240 - val_accuracy: 0.9470 - val_loss: 0.2412
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9935 - loss: 0.0242 - val_accuracy: 0.9470 - val_loss: 0.2444
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9939 - loss: 0.0239 - val_accuracy: 0.9470 - val_loss: 0.2444
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9939 - loss: 0.0230 - val_accuracy: 0.9484 - val_loss: 0.2434
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9935 - loss: 0.0229 - val_accuracy: 0.9470 - val_loss: 0.2454
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9935 - loss: 0.0229 - val_accuracy: 0.9470 - val_loss: 0.2449
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9939 - loss: 0.0223 - val_accuracy: 0.9470 - val_loss: 0.2466
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9939 - loss: 0.0224 - val_accuracy: 0.9470 - val_loss: 0.2483
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9939 - loss: 0.0219 - val_accuracy: 0.9470 - val_loss: 0.2484
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9935 - loss: 0.0218 - val_accuracy: 0.9470 - val_loss: 0.2506
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9942 - loss: 0.0229 - val_accuracy: 0.9484 - val_loss: 0.2526
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9935 - loss: 0.0231 - val_accuracy: 0.9470 - val_loss: 0.2509
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9942 - loss: 0.0227 - val_accuracy: 0.9470 - val_loss: 0.2523

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(hist.history['loss'], label='Train')
ax.plot(hist.history['val_loss'], label='Validation')
ax.set_xlabel('Epoque')
ax.set_title('Entropie')
ax.legend(loc='best')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(hist.history['accuracy'], label='Train')
ax.plot(hist.history['val_accuracy'], label='Validation')
ax.set_xlabel('Epoque')
ax.set_title('Exactitude (accuracy)')
ax.legend(loc='best')
plt.show()

# %% [markdown]
# ### 2.4. Prévisions

# %%
y_test_pred = model.predict(X_test_norm)
y_test_pred[0:5]
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# array([[5.5875504e-01],
#        [9.9999452e-01],
#        [9.9926728e-01],
#        [1.3417700e-07],
#        [9.9751097e-01]], dtype=float32)

# %%
y_test_pred_classes = (y_test_pred > 0.5).astype(int)
y_test_pred_classes[0:5]
# Out:
# array([[1],
#        [1],
#        [1],
#        [0],
#        [1]])

# %%
score_test = model.evaluate(X_test_norm, y_test, verbose=0)
print(f'Entropie test   : {score_test[0]:4.4f}')
print(f'Exactitude test : {score_test[1]:4.4f}')
# Out:
# Entropie test   : 0.2505
# Exactitude test : 0.9403
